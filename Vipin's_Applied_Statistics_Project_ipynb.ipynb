# %% [markdown]
# <a href="https://colab.research.google.com/github/Vipin1184/Data-Visualisation-file/blob/main/Vipin's_Applied_Statistics_Project_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %%
# Importing necessary libraries.
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
# Loading the dataset.
df = pd.read_csv('/content/Superstore Marketing Data.csv')

# Displaying first 5 rows of the data.
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
# Displaying last 5 rows of the data.
df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
# Checking the shape of the data.
df.shape
# Out:
# (2240, 22)

# %%
# Checking missing values in the data.
missing_values = df.isnull().sum()
missing_values
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
# Handling the missing values in 'Income' column of the dataset.
df['Income'].fillna(df['Income'].mean(), inplace=True)
# Out:
# <ipython-input-76-3b869197b551>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Income'].fillna(df['Income'].mean(), inplace=True)

# %%
# Again checking for missing or null values, after handling.
df.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %%
# Checking for duplicated values in the dataset.
duplicated_values = df.duplicated().sum()
duplicated_values
# Out:
# np.int64(0)

# %%
# Checking the data type of the columns by the info method.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Converting data type of 'Dt_Customer' column from Object to datetime frame.
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'], errors='coerce')

# Again checking for data types after handling.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          1324 non-null   datetime64[ns]
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# displaying the cleaned dataset.
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0  2014-06-16        0       189  ...              111
# ...

# %%
# Checking the summary of the data.
df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35538.750000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51741.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68289.750000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
# std     3246.662198    11.984069   25037.797168     0.538398     0.544538
#
#                          Dt_Customer      Recency     MntWines    MntFruits  \
# count                           1324  2240.000000  2240.000000  2240.000000
# mean   2013-07-19 09:00:32.628398848    49.109375   303.935714    26.302232
# ...

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# ## Measures of Central Tendency##

# %%
Key_variables = ['Income','MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds'] # Some key variables from the dataset.

# Calculating the mean of the variables.
mean = df[Key_variables].mean()
print(f"Mean of the variables are :\n {mean}")
# Out:
# Mean of the variables are :
#  Income              52247.251354
# MntWines              303.935714
# MntFruits              26.302232
# MntMeatProducts       166.950000
# MntFishProducts        37.525446
# MntSweetProducts       27.062946
# MntGoldProds           44.021875
# dtype: float64

# %%
# Calculating the mode of the variables.
Mode = df[Key_variables].mode()
print(f"Mode of the variables are :\n {Mode}")
# Out:
# Mode of the variables are :
#           Income  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  52247.251354         2          0                7                0
#
#    MntSweetProducts  MntGoldProds
# 0                 0             1

# %%
# Calculating the median of the variables.
Median = df[Key_variables].median()
print(f"Median of the variables are :\n {Median}")
# Out:
# Median of the variables are :
#  Income              51741.5
# MntWines              173.5
# MntFruits               8.0
# MntMeatProducts        67.0
# MntFishProducts        12.0
# MntSweetProducts        8.0
# MntGoldProds           24.0
# dtype: float64

# %% [markdown]
# ## Measures Of Dispersion##

# %%
# Calculating the variance of the variables.
Variance = df[Key_variables].var()
print(f"Variance of the variables are :\n {Variance}")
# Out:
# Variance of the variables are :
#  Income              6.268913e+08
# MntWines            1.132978e+05
# MntFruits           1.581926e+03
# MntMeatProducts     5.094743e+04
# MntFishProducts     2.984325e+03
# MntSweetProducts    1.704080e+03
# MntGoldProds        2.721442e+03
# dtype: float64

# %%
# Calculating the standard deviation of the variables.
Standard_deviation = df[Key_variables].std()
print(f"Standard deviation of the variables are :\n {Standard_deviation}")
# Out:
# Standard deviation of the variables are :
#  Income              25037.797168
# MntWines              336.597393
# MntFruits              39.773434
# MntMeatProducts       225.715373
# MntFishProducts        54.628979
# MntSweetProducts       41.280498
# MntGoldProds           52.167439
# dtype: float64

# %% [markdown]
# ## Checking and Handling Outliers##

# %%
# Importing necessary libraries for visualizations.
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Key_variables = ['Income','MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds']

# Creating box plots for the key variables.
for variable in Key_variables:
    plt.figure(figsize=(6, 3))
    sns.boxplot(y=df[variable])
    plt.title(f'Box Plot of {variable}')
    plt.ylabel(variable)
    plt.show()

# %%
# Handling Outliers.
def remove_outliers(data, columns):
    for column in columns:
        Q1 = data[column].quantile(0.25)
        Q3 = data[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
    return data

Key_variables = ['Income','MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds']

# %%
# Setting new variable for future use.
new_df = remove_outliers(df, Key_variables)

# %%
# Again checking for outliers after handling.
Key_variables = ['Income','MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds']

for variable in Key_variables:
    plt.figure(figsize=(4, 4))
    sns.boxplot(y=new_df[variable])
    plt.title(f'Box Plot of {variable} (Outliers Removed)')
    plt.ylabel(variable)
    plt.show()

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# #### Here the columns present in the Key_variables(taken by me) don't have data necessary for binomial distribution. So we are cheking for normal distribution only. ####

# %%
# Checking for Normal Distribution:
Key_variables = ['Income','MntWines','MntFruits','MntMeatProducts','MntFishProducts','MntSweetProducts','MntGoldProds']

# Iterating through each variable and creating a histogram.
for variable in Key_variables:
    plt.figure(figsize=(6, 4))
    sns.histplot(new_df[variable], kde=True)
    plt.title(f'Histogram of {variable}')
    plt.xlabel(variable)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# #### By making histogram, we came to know that only 'Income' column shows normal distribution; Hence we are calculating probability distribution and expected value only for 'Income' column. ####

# %%
mean = new_df['Income'].mean()
std = new_df['Income'].std()

# Probability of income less than or equal to 45000
prob_less_than_45000 = stats.norm.cdf(45000, mean, std)
print(f"Probability of Income <= 45000: {prob_less_than_45000}")

# Probability of income grater than 45000
prob_more_than_45000 = 1 - prob_less_than_45000
print(f"Probability of Income > 45000: {prob_more_than_45000}")

# Expected income
expected_income = mean
print(f"Expected Income: {expected_income}")
# Out:
# Probability of Income <= 45000: 0.6544141713628822
# Probability of Income > 45000: 0.34558582863711784
# Expected Income: 39098.1527928199

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %%
# Calculating the correlation matrix for all numerical columns.
numerical_df = new_df.select_dtypes(include=np.number)
correlation_matrix = numerical_df.corr().round(2)
correlation_matrix
# Out:
#                        Id  Year_Birth  Income  Kidhome  Teenhome  Recency  \
# Id                   1.00        0.02   -0.02     0.01     -0.02    -0.03
# Year_Birth           0.02        1.00   -0.35     0.24     -0.53    -0.02
# Income              -0.02       -0.35    1.00    -0.30      0.49     0.00
# Kidhome              0.01        0.24   -0.30     1.00     -0.20     0.01
# Teenhome            -0.02       -0.53    0.49    -0.20      1.00     0.01
# Recency             -0.03       -0.02    0.00     0.01      0.01     1.00
# MntWines            -0.03       -0.22    0.65    -0.42      0.28    -0.01
# MntFruits           -0.04       -0.02    0.20    -0.23     -0.04     0.05
# MntMeatProducts     -0.03       -0.14    0.57    -0.29      0.15     0.01
# MntFishProducts     -0.06        0.03    0.14    -0.18     -0.09     0.03
# MntSweetProducts    -0.06        0.06    0.14    -0.16     -0.11     0.04
# MntGoldProds        -0.07       -0.09    0.26    -0.22      0.08     0.02
# ...

# %% [markdown]
# #### By checking the correlation between different numerical variables, we came to know that 'MntWines' and 'MntMeatProducts' variable is highly correlated to 'Income', 'NumWebPurchases', 'NumStorePurchases' and 'NumCatalogPurchases'. ####

# %%
education_groups = new_df.groupby('Education')
average_spending = education_groups[['MntWines', 'MntMeatProducts']].mean()
print(average_spending)
# Out:
#               MntWines  MntMeatProducts
# Education
# 2n Cycle     48.876106        23.477876
# Basic         2.632653         7.693878
# Graduation   92.259067        35.032815
# Master      167.568889        45.271111
# PhD         232.894558        47.775510

# %%
# Checking average spending of customers based on their Marital_Status.
education_groups = new_df.groupby('Marital_Status')
average_spending = education_groups[['MntWines', 'MntMeatProducts']].mean()
print(average_spending)
# Out:
#                   MntWines  MntMeatProducts
# Marital_Status
# Alone           184.666667        26.333333
# Divorced        150.261194        42.888060
# Married         135.592668        35.366599
# Single          108.865672        35.708955
# Together        128.769939        40.493865
# Widow           171.666667        41.222222
# YOLO            322.000000        50.000000

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %%
# Creating a scatter plot between Income and MntWines.
plt.scatter(new_df['Income'], new_df['MntWines'])
plt.xlabel('Income')
plt.ylabel('MntWines')
plt.title('Scatter Plot of Income vs MntWines')
plt.show()

# %%
# Creating a scatter plot between Income and MntGoldProds.
plt.scatter(new_df['Income'], new_df['MntGoldProds'])
plt.xlabel('Income')
plt.ylabel('MntGoldProds')
plt.title('Scatter Plot of Income vs MntGoldProds')
plt.show()

# %%
# Creating a scatter plot between Income and MntMeatProducts.
plt.scatter(new_df['Income'], new_df['MntMeatProducts'])
plt.xlabel('Income')
plt.ylabel('MntMeatProducts')
plt.title('Scatter Plot of Income vs MntMeatProducts')
plt.show()

# %%
# Creating a scatter plot of MntMeatProducts vs MntWines.
plt.scatter(new_df['MntMeatProducts'], new_df['MntWines'])
plt.xlabel('MntMeatProducts')
plt.ylabel('MntWines')
plt.title('Scatter Plot of MntMeantProducts vs MntWines')
plt.show()

# %%
# Creating a grouped bar chart of Average wine spending by education and marital status.
grouped_data = new_df.groupby(['Education', 'Marital_Status'])['MntWines'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x='Education', y='MntWines', hue='Marital_Status', data=grouped_data)
plt.title('Average Wine Spending by Education and Marital Status')
plt.xlabel('Education Level')
plt.ylabel('Average Wine Spending')
plt.legend(title='Marital Status')
plt.show()

# %%
# Creating a heatmap to visualize correlation between variables.
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Insights :
# 1. People with high Income are spending more on wine, meat, gold and fruits item.
# 2.  People with higher education levels, are spending more on items due to thier high income.
# 3. Alone and yolo person are spending more on wines and meats.
# 4. People who buy meats are also buy wines.
# 5. People are more preffering stores to buy products rather than web mode or catalog mode.

# %% [markdown]
# ### Recommendations :
# 1. We should offer discounts and promotions on wines and meat products for customers with higher education levels.
# 2. We should also offer discounts and promotions for alone and yolo persons as they are our profitable customers.
# 3. We should enhance online shopping experience to increase web purchases.
# 4. We should also focus on sales and marketing efforts of other things like fruits, fish and golds etc.

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
